# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("log.csv",sep=r"\s+")

# %%
df
# Out:
#        i  init_energy  atom_p.energy  atom_t1.energy  atom_t2.energy  \
# 0      0     4.774071       4.493237        0.000597        0.280238
# 1      1     1.658944       1.603600        0.000541        0.054803
# 2      2     4.570311       4.502169        0.000268        0.067874
# 3      3     6.394314       6.388873        0.004916        0.000525
# 4      4     5.158714       5.126190        0.024338        0.008186
# ..   ...          ...            ...             ...             ...
# 96    96     8.335230       8.327038        0.000135        0.008057
# 97    97     3.210617       3.008395        0.103365        0.098858
# 98    98     2.519071       2.514189        0.004463        0.000419
# 99    99     8.132099       8.114366        0.010216        0.007517
# 100  100     3.052429       3.045570        0.000193        0.006666
#
#      atom_t1_p  atom_t1_px  atom_t1_py  atom_t1_pz  atom_t2_p  atom_t2_px  \
# 0     0.169228    0.117488    0.121766   -0.002744   3.667615    2.284014
# 1     0.161200    0.068731    0.145753   -0.004196   1.621895   -0.034567
# 2     0.113368    0.084106    0.076006   -0.001245   1.804982    1.406092
# 3     0.485754    0.334331   -0.351866   -0.019249   0.158710   -0.000282
# 4     1.080843    1.018026   -0.347213   -0.106246   0.626835    0.031653
# ..         ...         ...         ...         ...        ...         ...
# 96    0.080491    0.060846    0.052691   -0.000463   0.621889    0.500134
# 97    2.227443    2.124801    0.331656   -0.580282   2.178345   -0.341934
# 98    0.462856   -0.364672    0.283679   -0.027852   0.141846   -0.141822
# 99    0.700251   -0.164763    0.679666   -0.035483   0.600675   -0.592469
# 100   0.096230    0.023890    0.093211   -0.001094   0.565656   -0.138975
#
#      atom_t2_py  atom_t2_pz  atom_p_p  atom_p_px  atom_p_py  atom_p_pz
# 0      2.563930   -1.288776  5.995490  -2.370973  -2.651554  -4.826349
# 1      1.564902   -0.424770  3.581731  -0.033607  -1.682763  -3.161642
# 2      1.086894   -0.315478  6.001446  -1.482231  -1.156683  -5.699336
# 3     -0.158696   -0.002055  7.149195  -0.333684   0.510006  -7.123169
# 4     -0.625015   -0.035735  6.403868  -1.043298   0.966317  -6.243980
# ..          ...         ...       ...        ...        ...        ...
# 96     0.368576   -0.027634  8.161881  -0.560562  -0.420953  -8.131720
# 97    -2.078524   -0.554982  4.905829  -1.877731   1.839816  -4.142024
# 98     0.000238   -0.002616  4.484809   0.505195  -0.283188  -4.447257
# 99     0.095444   -0.026109  8.056980   0.755336  -0.773170  -7.984147
# 100    0.547014   -0.037792  4.936047   0.114861  -0.638978  -4.893166
#
# [101 rows x 17 columns]

# %%
loss_energy = df['atom_p.energy'] + df['atom_t1.energy'] + df['atom_t2.energy'] - df['init_energy']

# %%
init_pz = -np.sqrt(df['init_energy'] * 12 * 2)

# %%
after_pz = df['atom_p_px'] + df['atom_t1_px'] + df['atom_t2_px']

# %%
after_px
# Out:
# 0      0.030529
# 1      0.000557
# 2      0.007967
# 3      0.000364
# 4      0.006381
#          ...
# 96     0.000419
# 97    -0.094864
# 98    -0.001299
# 99    -0.001896
# 100   -0.000224
# Length: 101, dtype: float64
