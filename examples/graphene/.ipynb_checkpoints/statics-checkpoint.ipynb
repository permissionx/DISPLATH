# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np

# %%
df = pd.read_csv("p.debug.log")

# %%
dpx = df.px0 - df.px1
dpy = df.py0 - df.py1
dpz = df.pz0 - df.pz1

# %%
fig, axs = plt.subplots(3,1,figsize=(10,8))
for ax, data in zip(axs, [dpx,dpy, dpz]):
    ax.hist(data, bins = 50, density = True)
    ax.set_yscale("log")

# %%
fig, axs = plt.subplots(1,3,figsize=(13,4))
for ax, xdata, ydata in zip(axs, [df.px0, df.py0, df.pz0],[dpx,dpy, dpz]):
    ax.scatter(np.abs(xdata), np.abs(ydata))

# %%
df
# Out:
#       nrun        px0        py0         pz0           px1           py1  \
# 0        1   0.000000   0.000000 -200.000000 -6.927109e-05  1.206762e-03
# 1        2   0.000000   0.000000 -200.000000 -1.773562e+00 -2.225263e+00
# 2        2  40.179771  49.864795  -50.092328  4.017977e+01  4.986480e+01
# 3        3   0.000000   0.000000 -200.000000 -1.839893e-02  7.215121e-04
# 4        3   7.466745   1.731890   -0.966019  7.857942e+00  2.055739e+00
# ...    ...        ...        ...         ...           ...           ...
# 1114  9819   0.000000   0.000000 -200.000000  0.000000e+00  0.000000e+00
# 1115  9841   0.000000   0.000000 -200.000000  8.881784e-16  0.000000e+00
# 1116  9844   0.000000   0.000000 -200.000000  0.000000e+00  0.000000e+00
# 1117  9851   0.000000   0.000000 -200.000000  0.000000e+00 -1.776357e-15
# 1118  9984   0.000000   0.000000 -200.000000  0.000000e+00 -2.220446e-16
#
#              pz1
# 0    -200.033563
# 1    -206.722633
# 2     -50.092328
# 3    -200.196630
# 4      -0.627256
# ...          ...
# 1114 -200.000000
# 1115 -200.000000
# 1116 -200.000000
# 1117 -200.000000
# 1118 -200.000000
#
# [1119 rows x 7 columns]
